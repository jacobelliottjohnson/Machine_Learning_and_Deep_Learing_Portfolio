# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product " />
# </a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/cc-logo-square.png" width="200" alt="cognitiveclass.ai logo" />

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip

# %%
# !unzip -q Positive_tensors.zip

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)
import torchvision.models as models

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/home/dsxuser/work"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
model = models.resnet18(pretrained=True)

mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]



train_dataset=Dataset(train=True)
validation_dataset=Dataset(train=False)

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
input_dim = 512
output_dim = 2
    
model.fc = nn.Linear(input_dim, output_dim)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
batch = 100
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=batch)

# %%
for param in model.parameters():
  if param.requires_grad:
    print(param)
# Out:
# Parameter containing:
# tensor([[ 0.0342, -0.0255,  0.0249,  ...,  0.0130, -0.0365, -0.0426],
#         [ 0.0411, -0.0204,  0.0384,  ...,  0.0156, -0.0340,  0.0069]],
#        requires_grad=True)
# Parameter containing:
# tensor([0.0074, 0.0091], requires_grad=True)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs=1
loss_list=[]
accuracy_list=[]
correct=0
N_test=len(validation_dataset)
N_train=len(train_dataset)
start_time = time.time()
#n_epochs

Loss=0
start_time = time.time()
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/batch)))
        i_start_time = time.time()

        model.train() 
        optimizer.zero_grad()
        z = model(x)
        loss = criterion(z, y)
        loss.backward()
        optimizer.step()
        loss_list.append(loss.data)
        print("Finished in {} (s)".format(time.time()-i_start_time))
        
        
       
       
    # perform a prediction on the validation data 
    correct = 0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/batch)))
        i_start_time = time.time()
        z = model(x)
        _, yhat = torch.max(z.data, 1)
        correct += (yhat == y_test).sum().item()
        print("Finished in {} (s)".format(time.time()-i_start_time))
        
    accuracy = correct / N_test
    loss_list.append(loss.data)
    accuracy_list.append(accuracy)
# Out:
# Iteration (train phase) 1/300
# Finished in 4.97513222694397 (s)
# Iteration (train phase) 2/300
# Finished in 4.759842872619629 (s)
# Iteration (train phase) 3/300
# Finished in 4.810381889343262 (s)
# Iteration (train phase) 4/300
# Finished in 4.800408363342285 (s)
# Iteration (train phase) 5/300
# Finished in 4.890705585479736 (s)
# Iteration (train phase) 6/300
# Finished in 4.898924827575684 (s)
# Iteration (train phase) 7/300
# Finished in 4.886812686920166 (s)
# Iteration (train phase) 8/300
# Finished in 4.8288304805755615 (s)
# Iteration (train phase) 9/300
# Finished in 4.946636199951172 (s)
# Iteration (train phase) 10/300
# Finished in 5.014335632324219 (s)
# Iteration (train phase) 11/300
# Finished in 4.876513242721558 (s)
# Iteration (train phase) 12/300
# Finished in 4.959874153137207 (s)
# Iteration (train phase) 13/300
# Finished in 4.874369144439697 (s)
# Iteration (train phase) 14/300
# Finished in 5.009589195251465 (s)
# Iteration (train phase) 15/300
# Finished in 4.8556132316589355 (s)
# Iteration (train phase) 16/300
# Finished in 4.8061137199401855 (s)
# Iteration (train phase) 17/300
# Finished in 4.785993576049805 (s)
# Iteration (train phase) 18/300
# Finished in 5.121596097946167 (s)
# Iteration (train phase) 19/300
# Finished in 5.020686626434326 (s)
# Iteration (train phase) 20/300
# Finished in 5.092608690261841 (s)
# Iteration (train phase) 21/300
# Finished in 4.889204978942871 (s)
# Iteration (train phase) 22/300
# Finished in 4.906597137451172 (s)
# Iteration (train phase) 23/300
# Finished in 4.7844274044036865 (s)
# Iteration (train phase) 24/300
# Finished in 4.9976465702056885 (s)
# Iteration (train phase) 25/300
# Finished in 4.846327781677246 (s)
# Iteration (train phase) 26/300
# Finished in 4.977141380310059 (s)
# Iteration (train phase) 27/300
# Finished in 5.012648105621338 (s)
# Iteration (train phase) 28/300
# Finished in 4.9238200187683105 (s)
# Iteration (train phase) 29/300
# Finished in 4.945066213607788 (s)
# Iteration (train phase) 30/300
# Finished in 5.032588243484497 (s)
# Iteration (train phase) 31/300
# Finished in 4.908743619918823 (s)
# Iteration (train phase) 32/300
# Finished in 4.892589330673218 (s)
# Iteration (train phase) 33/300
# Finished in 4.858226537704468 (s)
# Iteration (train phase) 34/300
# Finished in 4.810841798782349 (s)
# Iteration (train phase) 35/300
# Finished in 4.894205093383789 (s)
# Iteration (train phase) 36/300
# Finished in 5.118974685668945 (s)
# Iteration (train phase) 37/300
# Finished in 4.966091156005859 (s)
# Iteration (train phase) 38/300
# Finished in 4.889185428619385 (s)
# Iteration (train phase) 39/300
# Finished in 4.878675699234009 (s)
# Iteration (train phase) 40/300
# Finished in 4.757160663604736 (s)
# Iteration (train phase) 41/300
# Finished in 4.880956411361694 (s)
# Iteration (train phase) 42/300
# Finished in 4.792453765869141 (s)
# Iteration (train phase) 43/300
# Finished in 4.845067024230957 (s)
# Iteration (train phase) 44/300
# Finished in 4.873048305511475 (s)
# Iteration (train phase) 45/300
# Finished in 5.046229600906372 (s)
# Iteration (train phase) 46/300
# Finished in 4.754469633102417 (s)
# Iteration (train phase) 47/300
# Finished in 5.011602878570557 (s)
# Iteration (train phase) 48/300
# Finished in 4.862549304962158 (s)
# Iteration (train phase) 49/300
# Finished in 4.844035387039185 (s)
# Iteration (train phase) 50/300
# Finished in 4.742326021194458 (s)
# Iteration (train phase) 51/300
# Finished in 4.92036247253418 (s)
# Iteration (train phase) 52/300
# Finished in 4.914305925369263 (s)
# Iteration (train phase) 53/300
# Finished in 4.885715484619141 (s)
# Iteration (train phase) 54/300
# Finished in 4.85301399230957 (s)
# Iteration (train phase) 55/300
# Finished in 4.901183605194092 (s)
# Iteration (train phase) 56/300
# Finished in 4.969781160354614 (s)
# Iteration (train phase) 57/300
# Finished in 4.812347412109375 (s)
# Iteration (train phase) 58/300
# Finished in 5.082137823104858 (s)
# Iteration (train phase) 59/300
# Finished in 4.920939683914185 (s)
# Iteration (train phase) 60/300
# Finished in 4.845223903656006 (s)
# Iteration (train phase) 61/300
# Finished in 4.781970977783203 (s)
# Iteration (train phase) 62/300
# Finished in 4.778237342834473 (s)
# Iteration (train phase) 63/300
# Finished in 4.831411838531494 (s)
# Iteration (train phase) 64/300
# Finished in 4.8808207511901855 (s)
# Iteration (train phase) 65/300
# Finished in 4.881582736968994 (s)
# Iteration (train phase) 66/300
# Finished in 4.855925798416138 (s)
# Iteration (train phase) 67/300
# Finished in 4.888925790786743 (s)
# Iteration (train phase) 68/300
# Finished in 4.9064695835113525 (s)
# Iteration (train phase) 69/300
# Finished in 4.89991569519043 (s)
# Iteration (train phase) 70/300
# Finished in 4.828341722488403 (s)
# Iteration (train phase) 71/300
# Finished in 4.838556528091431 (s)
# Iteration (train phase) 72/300
# Finished in 4.918144464492798 (s)
# Iteration (train phase) 73/300
# Finished in 4.800963401794434 (s)
# Iteration (train phase) 74/300
# Finished in 4.8202269077301025 (s)
# Iteration (train phase) 75/300
# Finished in 4.785674571990967 (s)
# Iteration (train phase) 76/300
# Finished in 4.803961515426636 (s)
# Iteration (train phase) 77/300
# Finished in 4.871990442276001 (s)
# Iteration (train phase) 78/300
# Finished in 4.866254091262817 (s)
# Iteration (train phase) 79/300
# Finished in 4.815551280975342 (s)
# Iteration (train phase) 80/300
# Finished in 4.821585655212402 (s)
# Iteration (train phase) 81/300
# Finished in 4.925018787384033 (s)
# Iteration (train phase) 82/300
# Finished in 4.850271940231323 (s)
# Iteration (train phase) 83/300
# Finished in 4.939091205596924 (s)
# Iteration (train phase) 84/300
# Finished in 4.8596251010894775 (s)
# Iteration (train phase) 85/300
# Finished in 4.883597373962402 (s)
# Iteration (train phase) 86/300
# Finished in 4.877113580703735 (s)
# Iteration (train phase) 87/300
# Finished in 4.908822536468506 (s)
# Iteration (train phase) 88/300
# Finished in 4.897478342056274 (s)
# Iteration (train phase) 89/300
# Iteration (train phase) 185/300
# Finished in 4.865290403366089 (s)
# Iteration (train phase) 186/300
# Finished in 4.97944712638855 (s)
# Iteration (train phase) 187/300
# Finished in 4.92897629737854 (s)
# Iteration (train phase) 188/300
# Finished in 4.969090938568115 (s)
# Iteration (train phase) 189/300
# Finished in 4.8566389083862305 (s)
# Iteration (train phase) 190/300
# Finished in 4.870318174362183 (s)
# Iteration (train phase) 191/300
# Finished in 4.754796504974365 (s)
# Iteration (train phase) 192/300
# Finished in 4.92861270904541 (s)
# Iteration (train phase) 193/300
# Finished in 4.836249589920044 (s)
# Iteration (train phase) 194/300
# Finished in 4.705533027648926 (s)
# Iteration (train phase) 195/300
# Finished in 4.893566846847534 (s)
# Iteration (train phase) 196/300
# Finished in 4.854917049407959 (s)
# Iteration (train phase) 197/300
# Finished in 4.865436553955078 (s)
# Iteration (train phase) 198/300
# Finished in 4.7354576587677 (s)
# Iteration (train phase) 199/300
# Finished in 4.890948295593262 (s)
# Iteration (train phase) 200/300
# Finished in 4.929683446884155 (s)
# Iteration (train phase) 201/300
# Finished in 4.902129173278809 (s)
# Iteration (train phase) 202/300
# Finished in 5.019953966140747 (s)
# Iteration (train phase) 203/300
# Finished in 5.022132873535156 (s)
# Iteration (train phase) 204/300
# Finished in 4.937443494796753 (s)
# Iteration (train phase) 205/300
# Finished in 4.896071910858154 (s)
# Iteration (train phase) 206/300
# Finished in 4.868649244308472 (s)
# Iteration (train phase) 207/300
# Finished in 4.876872539520264 (s)
# Iteration (train phase) 208/300
# Finished in 4.829677581787109 (s)
# Iteration (train phase) 209/300
# Finished in 4.891171932220459 (s)
# Iteration (train phase) 210/300
# Finished in 4.8595194816589355 (s)
# Iteration (train phase) 211/300
# Finished in 4.933936834335327 (s)
# Iteration (train phase) 212/300
# Finished in 4.791985511779785 (s)
# Iteration (train phase) 213/300
# Finished in 4.827986240386963 (s)
# Iteration (train phase) 214/300
# Finished in 4.847762107849121 (s)
# Iteration (train phase) 215/300
# Finished in 4.846872568130493 (s)
# Iteration (train phase) 216/300
# Finished in 4.907746076583862 (s)
# Iteration (train phase) 217/300
# Finished in 4.802358388900757 (s)
# Iteration (train phase) 218/300
# Finished in 4.921114444732666 (s)
# Iteration (train phase) 219/300
# Finished in 4.783571243286133 (s)
# Iteration (train phase) 220/300
# Finished in 4.916519403457642 (s)
# Iteration (train phase) 221/300
# Finished in 4.708277940750122 (s)
# Iteration (train phase) 222/300
# Finished in 4.787249565124512 (s)
# Iteration (train phase) 223/300
# Finished in 4.774773597717285 (s)
# Iteration (train phase) 224/300
# Finished in 4.85927414894104 (s)
# Iteration (train phase) 225/300
# Finished in 4.801453113555908 (s)
# Iteration (train phase) 226/300
# Finished in 4.850037574768066 (s)
# Iteration (train phase) 227/300
# Finished in 4.9073381423950195 (s)
# Iteration (train phase) 228/300
# Finished in 4.879271984100342 (s)
# Iteration (train phase) 229/300
# Finished in 4.9135541915893555 (s)
# Iteration (train phase) 230/300
# Finished in 4.8408191204071045 (s)
# Iteration (train phase) 231/300
# Finished in 4.680011987686157 (s)
# Iteration (train phase) 232/300
# Finished in 4.9006876945495605 (s)
# Iteration (train phase) 233/300
# Finished in 4.830084323883057 (s)
# Iteration (train phase) 234/300
# Finished in 4.83540415763855 (s)
# Iteration (train phase) 235/300
# Finished in 4.719632148742676 (s)
# Iteration (train phase) 236/300
# Finished in 4.954509019851685 (s)
# Iteration (train phase) 237/300
# Finished in 4.820424795150757 (s)
# Iteration (train phase) 238/300
# Finished in 4.861433744430542 (s)
# Iteration (train phase) 239/300
# Finished in 4.913267374038696 (s)
# Iteration (train phase) 240/300
# Finished in 4.775339126586914 (s)
# Iteration (train phase) 241/300
# Finished in 4.769851207733154 (s)
# Iteration (train phase) 242/300
# Finished in 4.975524187088013 (s)
# Iteration (train phase) 243/300
# Finished in 4.99495267868042 (s)
# Iteration (train phase) 244/300
# Finished in 4.954733848571777 (s)
# Iteration (train phase) 245/300
# Finished in 4.919081687927246 (s)
# Iteration (train phase) 246/300
# Finished in 4.797016382217407 (s)
# Iteration (train phase) 247/300
# Finished in 4.921658515930176 (s)
# Iteration (train phase) 248/300
# Finished in 4.966407060623169 (s)
# Iteration (train phase) 249/300
# Finished in 4.857386112213135 (s)
# Iteration (train phase) 250/300
# Finished in 4.985571384429932 (s)
# Iteration (train phase) 251/300
# Finished in 4.75108003616333 (s)
# Iteration (train phase) 252/300
# Finished in 4.848758220672607 (s)
# Iteration (train phase) 253/300
# Finished in 4.946518898010254 (s)
# Iteration (train phase) 254/300
# Finished in 4.907906770706177 (s)
# Iteration (train phase) 255/300
# Finished in 4.762284517288208 (s)
# Iteration (train phase) 256/300
# Finished in 4.706672668457031 (s)
# Iteration (train phase) 257/300
# Finished in 4.898473262786865 (s)
# Iteration (train phase) 258/300
# Finished in 4.803974628448486 (s)
# Iteration (train phase) 259/300
# Finished in 4.973598957061768 (s)
# Iteration (train phase) 260/300
# Finished in 4.75759220123291 (s)
# Iteration (train phase) 261/300
# Finished in 4.880162477493286 (s)
# Iteration (train phase) 262/300
# Finished in 4.8979949951171875 (s)
# Iteration (train phase) 263/300
# Finished in 4.89745020866394 (s)
# Iteration (train phase) 264/300
# Finished in 4.9090735912323 (s)
# Iteration (train phase) 265/300
# Finished in 4.893752574920654 (s)
# Iteration (train phase) 266/300
# Finished in 4.912716388702393 (s)
# Iteration (train phase) 267/300
# Finished in 5.015045166015625 (s)
# Iteration (train phase) 268/300
# Finished in 4.86842679977417 (s)
# Iteration (train phase) 269/300
# Finished in 4.96686577796936 (s)
# Iteration (train phase) 270/300
# Finished in 4.842484474182129 (s)
# Iteration (train phase) 271/300
# Finished in 4.887299299240112 (s)
# Iteration (train phase) 272/300
# Finished in 4.804378986358643 (s)
# Iteration (train phase) 273/300
# Finished in 4.85656213760376 (s)
# Iteration (train phase) 274/300
# Finished in 4.952328205108643 (s)
# Iteration (train phase) 275/300
# Finished in 4.851839542388916 (s)
# Iteration (train phase) 276/300
# Finished in 4.962784290313721 (s)
# Iteration (train phase) 277/300
# Finished in 4.864042520523071 (s)
# Iteration (train phase) 278/300
# Finished in 4.7849626541137695 (s)
# Iteration (train phase) 279/300
# Finished in 4.885824918746948 (s)
# Iteration (train phase) 280/300
# Finished in 4.866318941116333 (s)
# Iteration (train phase) 281/300
# Finished in 4.868621587753296 (s)
# Iteration (train phase) 282/300
# Finished in 4.882672548294067 (s)
# Iteration (train phase) 283/300
# Finished in 4.90471076965332 (s)
# Iteration (train phase) 284/300
# Finished in 4.985607624053955 (s)
# Iteration (train phase) 285/300
# Finished in 4.856201410293579 (s)
# Iteration (train phase) 286/300
# Finished in 4.785506248474121 (s)
# Iteration (train phase) 287/300
# Finished in 4.982000827789307 (s)
# Iteration (train phase) 288/300
# Finished in 4.720776319503784 (s)
# Iteration (train phase) 289/300
# Finished in 5.00639271736145 (s)
# Iteration (train phase) 290/300
# Finished in 4.815679550170898 (s)
# Iteration (train phase) 291/300
# Finished in 4.871236801147461 (s)
# Iteration (train phase) 292/300
# Finished in 4.760322570800781 (s)
# Iteration (train phase) 293/300
# Finished in 4.772642612457275 (s)
# Iteration (train phase) 294/300
# Finished in 4.785433292388916 (s)
# Iteration (train phase) 295/300
# Finished in 4.853518486022949 (s)
# Iteration (train phase) 296/300
# Finished in 4.884577035903931 (s)
# Iteration (train phase) 297/300
# Finished in 4.873372316360474 (s)
# Iteration (train phase) 298/300
# Finished in 4.897063255310059 (s)
# Iteration (train phase) 299/300
# Finished in 4.7701451778411865 (s)
# Iteration (train phase) 300/300
# Finished in 4.836690187454224 (s)
# Iteration (validation phase) 1/100
# Finished in 4.763979196548462 (s)
# Iteration (validation phase) 2/100
# Finished in 4.746485471725464 (s)
# Iteration (validation phase) 3/100
# Finished in 5.072131633758545 (s)
# Iteration (validation phase) 4/100
# Finished in 4.915254831314087 (s)
# Iteration (validation phase) 5/100
# Finished in 4.6968419551849365 (s)
# Iteration (validation phase) 6/100
# Finished in 4.82106351852417 (s)
# Iteration (validation phase) 7/100
# Finished in 4.915307998657227 (s)
# Iteration (validation phase) 8/100
# Finished in 4.892735481262207 (s)
# Iteration (validation phase) 9/100
# Finished in 4.798786401748657 (s)
# Iteration (validation phase) 10/100
# Finished in 4.904435157775879 (s)
# Iteration (validation phase) 11/100
# Finished in 4.768845319747925 (s)
# Iteration (validation phase) 12/100
# Finished in 4.9109673500061035 (s)
# Iteration (validation phase) 13/100
# Finished in 4.726382493972778 (s)
# Iteration (validation phase) 14/100
# Finished in 4.925441265106201 (s)
# Iteration (validation phase) 15/100
# Finished in 4.86602258682251 (s)
# Iteration (validation phase) 16/100
# Finished in 4.888132095336914 (s)
# Iteration (validation phase) 17/100
# Finished in 4.875420093536377 (s)
# Iteration (validation phase) 18/100
# Finished in 4.870010852813721 (s)
# Iteration (validation phase) 19/100
# Finished in 4.734955072402954 (s)
# Iteration (validation phase) 20/100
# Finished in 4.81920313835144 (s)
# Iteration (validation phase) 21/100
# Finished in 4.882450580596924 (s)
# Iteration (validation phase) 22/100
# Finished in 4.855785131454468 (s)
# Iteration (validation phase) 23/100
# Finished in 4.781671762466431 (s)
# Iteration (validation phase) 24/100
# Finished in 4.73217248916626 (s)
# Iteration (validation phase) 25/100
# Finished in 4.8343517780303955 (s)
# Iteration (validation phase) 26/100
# Finished in 4.770444869995117 (s)
# Iteration (validation phase) 27/100
# Iteration (validation phase) 74/100
# Finished in 4.874219655990601 (s)
# Iteration (validation phase) 75/100
# Finished in 4.904465675354004 (s)
# Iteration (validation phase) 76/100
# Finished in 4.879476070404053 (s)
# Iteration (validation phase) 77/100
# Finished in 4.794585704803467 (s)
# Iteration (validation phase) 78/100
# Finished in 4.829788684844971 (s)
# Iteration (validation phase) 79/100
# Finished in 4.831453084945679 (s)
# Iteration (validation phase) 80/100
# Finished in 4.75370979309082 (s)
# Iteration (validation phase) 81/100
# Finished in 4.937761306762695 (s)
# Iteration (validation phase) 82/100
# Finished in 5.025019407272339 (s)
# Iteration (validation phase) 83/100
# Finished in 4.96070671081543 (s)
# Iteration (validation phase) 84/100
# Finished in 5.086312294006348 (s)
# Iteration (validation phase) 85/100
# Finished in 4.946902513504028 (s)
# Iteration (validation phase) 86/100
# Finished in 4.983332395553589 (s)
# Iteration (validation phase) 87/100
# Finished in 5.132695913314819 (s)
# Iteration (validation phase) 88/100
# Finished in 5.201981067657471 (s)
# Iteration (validation phase) 89/100
# Finished in 4.876888036727905 (s)
# Iteration (validation phase) 90/100
# Finished in 5.041753768920898 (s)
# Iteration (validation phase) 91/100
# Finished in 5.197176694869995 (s)
# Iteration (validation phase) 92/100
# Finished in 5.301846981048584 (s)
# Iteration (validation phase) 93/100
# Finished in 4.958228349685669 (s)
# Iteration (validation phase) 94/100
# Finished in 4.986512660980225 (s)
# Iteration (validation phase) 95/100
# Finished in 4.983896493911743 (s)
# Iteration (validation phase) 96/100
# Finished in 5.052976369857788 (s)
# Iteration (validation phase) 97/100
# Finished in 5.157451868057251 (s)
# Iteration (validation phase) 98/100
# Finished in 5.081579208374023 (s)
# Iteration (validation phase) 99/100
# Finished in 5.149286270141602 (s)
# Iteration (validation phase) 100/100
# Finished in 5.164826154708862 (s)
# Finished Accuracy 2102.4948806762695 (s).

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.99

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
count = 0
validation_loader_batch = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)

for i, (x_test, y_test) in enumerate(validation_loader_batch):
    # set model to eval
    model.eval()
    
    # make a prediction
    z = model(x_test)
    
    # find max
    _, yhat = torch.max(z.data, 1)
    
    # print mis-classified samples
    if yhat != y_test:
        print("Sample : {}; Expected Label: {}; Actual Label: {}".format(str(i), str(y_test), str(yhat)))
        count += 1
        if count >= 4:
            break
# Out:
# Sample : 76; Expected Label: tensor([1]); Actual Label: tensor([0])
# Sample : 295; Expected Label: tensor([0]); Actual Label: tensor([1])
# Sample : 420; Expected Label: tensor([1]); Actual Label: tensor([0])
# Sample : 557; Expected Label: tensor([0]); Actual Label: tensor([1])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.
